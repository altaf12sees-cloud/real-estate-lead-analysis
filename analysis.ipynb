# %%
# !pip install pandas scikit-learn openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# Load dataset (use exact file name)
df = pd.read_excel("crm_leads_analysis.xlsx")

# Show first rows
print("Preview data:")
print(df.head())

# Clean data
df = df.dropna()
df = df.drop_duplicates()

# Create target column
df['converted'] = df['Status'].apply(lambda x: 1 if str(x).lower() in ['converted', 'booked'] else 0)

# Select features
X = df[['LeadSource', 'PropertyType']]
y = df['converted']

# Convert text to numbers
X = pd.get_dummies(X)

# Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000, class_weight='balanced')
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("\nAccuracy:")
print(accuracy_score(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Preview data:
#         Name     ContactNo LeadSource          SubSource   Status  \
# 0   Lead 583  123456789583   Dubizzle  dubizzle whatsapp  Dropped
# 1   Lead 585  123456789585      Bayut     bayut whatsapp  Dropped
# 2   Lead 596  123456789596   Dubizzle  dubizzle whatsapp  Dropped
# 3  Lead 1165  123456790165   Dubizzle    landline number  Dropped
# 4  Lead 1265  123456790265     Direct    jebel ali hills   Booked
#
#            Reason EnquiryTypes PropertyType PropertySubType BHKTypes  ...  \
# 0  Exploring only         Rent  Residential       Apartment     3BHK  ...
# 1  Exploring only         Rent  Residential       Apartment     3BHK  ...
# 2  Exploring only         Rent  Residential       Apartment     1BHK  ...
# 3           agent         Rent  Residential       Apartment     3BHK  ...
# 4          Booked         Rent  Residential       Apartment     1BHK  ...
#
#            LastModifiedOn              ReceivedOn  MeetingsDoneCount  \
# 0  25-03-2026 03:43:44 PM  15-03-2026 11:32:13 AM                  0
# 1  25-03-2026 03:43:13 PM  16-03-2026 12:05:35 PM                  0
# 2  25-03-2026 03:41:35 PM  18-03-2026 11:41:34 PM                  0
# 3  14-03-2026 01:04:31 PM  13-03-2026 07:57:33 PM                  0
# 4  13-02-2026 01:28:38 PM  07-02-2026 09:08:28 AM                  0
#
#   MeetingsNotDoneCount SiteVisitsDoneCount SiteVisitsNotDoneCount  \
# 0                    0                   0                      1
# 1                    0                   0                      1
# 2                    0                   0                      0
# 3                    0                   0                      2
# 4                    0                   0                      0
#
#                PickedDate       ReEnquiredDate  \
# 0  15-03-2026 02:52:47 PM  01-01-0001 04:00 AM
# 1  16-03-2026 02:02:21 PM  01-01-0001 04:00 AM
# 2  25-03-2026 03:41:35 PM  01-01-0001 04:00 AM
# 3  14-03-2026 09:33:17 AM  01-01-0001 04:00 AM
# 4  10-02-2026 11:53:28 PM  01-01-0001 04:00 AM
#
#                                              Remarks  BookingValue
# 0                                     not interested             0
# 1                                     not interested             0
# 2                                     not interested             0
# 3  she confirmed the viewing at 12\nI was waiting...             0
# 4                         First booking by Ahmad Yar        105000
#
# [5 rows x 24 columns]
#
# Accuracy:
# 0.726474278544542
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.73      0.84       792
#            1       0.00      0.20      0.01         5
#
#     accuracy                           0.73       797
#    macro avg       0.50      0.46      0.43       797
# weighted avg       0.99      0.73      0.84       797
#
#
# Confusion Matrix:
# [[578 214]
#  [  4   1]]
